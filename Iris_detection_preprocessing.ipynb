# %%
import cv2
import numpy as np
import imutils
import glob
import os

# %% [markdown]
# ###Import image dataset

# %%
number=1215
label=242
imgs=[]

# %%
directory = r'/content/drive/MyDrive/image processing/UBIRIS_800_600/new_Sessao1'

# %%
os.chdir(directory)

# %%
os.listdir()
# Out:
# ['final_image.1.1.jpg',
#  'final_image.1.2.jpg',
#  'final_image.1.3.jpg',
#  'final_image.1.4.jpg',
#  'final_image.1.5.jpg',
#  'final_image.2.6.jpg',
#  'final_image.2.7.jpg',
#  'final_image.2.8.jpg',
#  'final_image.2.9.jpg',
#  'final_image.2.10.jpg',
#  'final_image.3.11.jpg',
#  'final_image.3.12.jpg',
#  'final_image.3.13.jpg',
#  'final_image.3.14.jpg',
#  'final_image.3.15.jpg',
#  'final_image.4.16.jpg',
#  'final_image.4.17.jpg',
#  'final_image.4.18.jpg',
#  'final_image.4.19.jpg',
#  'final_image.4.20.jpg',
#  'final_image.5.21.jpg',
#  'final_image.5.22.jpg',
#  'final_image.5.23.jpg',
#  'final_image.5.24.jpg',
#  'final_image.5.25.jpg',
#  'final_image.6.26.jpg',
#  'final_image.6.27.jpg',
#  'final_image.6.28.jpg',
#  'final_image.6.29.jpg',
#  'final_image.6.30.jpg',
#  'final_image.7.31.jpg',
#  'final_image.7.32.jpg',
#  'final_image.7.33.jpg',
#  'final_image.7.34.jpg',
#  'final_image.7.35.jpg',
#  'final_image.8.36.jpg',
#  'final_image.8.37.jpg',
# ...

# %%
for filepath in glob.iglob('/content/drive/MyDrive/image processing/UBIRIS_800_600/Sessao_2/*'):  #baraye har folder too sessao1
  for filepath in glob.iglob(filepath+'/*'):  # baraye hameye file ha dar har folder
    if filepath[-1]=='g':    #agar akharin harf file 'g' bood (image bood)
      img=cv2.imread(filepath) 
      imgs.append(img)
      img=cv2.resize(img,(200,150))
      cv2.imwrite('final_image'+'.'+str(label)+'.'+str(number)+'.jpg',img)
      number=number+1
  label=label+1

# %%
len(imgs)
# Out:
# 662

# %%
label
# Out:
# 374

# %%
len(os.listdir())
# Out:
# 1876
